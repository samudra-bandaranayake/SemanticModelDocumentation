# %% [markdown]
# # Run Notebooks

# %%
mssparkutils.notebook.run("0. Create Environment", 3600)
print("0. Create Environment Notebook execution completed!")

# %% [markdown]
# ## Assign Env to the Workspace

# %% [markdown]
# ## Create the Lakehouse

# %%
mssparkutils.notebook.run("0. Create Lake House", 3600)
print("0. Create Lake House Notebook execution completed!")

# %%
import sempy
import sempy.fabric as fabric
import pandas

# %%
# %run 2. Parameters

# %%
import notebookutils

workspace_id = fabric.get_workspace_id()

# lakehouse_name is already available from %run above
lh = notebookutils.lakehouse.get(lakehouse_name, workspace_id)
lakehouse_id = lh.id

spark.conf.set("spark.microsoft.defaultLakehouseId", lakehouse_id)
spark.conf.set("spark.microsoft.defaultLakehouseWorkspaceId", workspace_id)

print(f"✅ Lakehouse '{lakehouse_name}' ({lakehouse_id}) attached in workspace '{workspace_id}'")

# %%
# Check current lakehouse context
context = notebookutils.runtime.context
print(f"Lakehouse ID:           {context.get('defaultLakehouseId')}")
print(f"Lakehouse Name:         {context.get('defaultLakehouseName')}")
print(f"Lakehouse Workspace ID: {context.get('defaultLakehouseWorkspaceId')}")

# %% [markdown]
# mssparkutils.notebook.run(
#     "5. Data Transformation",
#     3600,
#     {"useRootDefaultLakehouse": True}
# )## Running the Load_Calc_Dependency_Data Notebook

# %%
mssparkutils.notebook.run(
    "4. Load Calc Dependency Data", 
    3600, 
    {"useRootDefaultLakehouse": True}
)
print("4. Load Calc Dependency Data Notebook execution completed!")

# %%
print(notebookutils.runtime.context)

# %% [markdown]
# ## Data Transformation and Save Data_Sources & Agent_Dax_Documentation

# %%
mssparkutils.notebook.run(
    "5. Data Transformation", 
    3600, 
    {"useRootDefaultLakehouse": True}
)
print("5. Data Transformation Data Notebook execution completed!")

# %%
mssparkutils.notebook.run(
    "6. Load Tables Columns", 
    3600, 
    {"useRootDefaultLakehouse": True}
)
print("6. Load Tables Columns Notebook execution completed!")

# %%
mssparkutils.notebook.run(
    "7. Load M Query", 
    3600, 
    {"useRootDefaultLakehouse": True}
)
print("7. Load M Query Notebook execution completed!")

# %%
mssparkutils.notebook.run(
    "8. Relationships", 
    3600, 
    {"useRootDefaultLakehouse": True}
)
print("8. Relationships Notebook execution completed!")

# %%
mssparkutils.notebook.run(
    "9. Extract Column List", 
    3600, 
    {"useRootDefaultLakehouse": True}
)
print("9. Extract Column List Notebook execution completed!")

# %%
mssparkutils.notebook.run(
    "10. Creating Semantic Model Diagram", #Creating_Semantic_Model_Diagram_LM
    3600, 
    {"useRootDefaultLakehouse": True}
)
print("10. Creating Semantic Model Diagram Notebook execution completed!")

# %%
mssparkutils.notebook.run(
    "11. RLS", #Creating_Semantic_Model_Diagram_LM
    3600, 
    {"useRootDefaultLakehouse": True}
)
print("11. RLS Notebook execution completed!")

# %%
mssparkutils.notebook.run(
    "12. Create Dim Database Table", #Creating_Semantic_Model_Diagram_LM
    3600, 
    {"useRootDefaultLakehouse": True}
)
print("12. Create Dim Database Table Notebook execution completed!")

# %% [markdown]
# ## Displaying output

# %%
df = spark.sql("SELECT * FROM SMD_LH.dim_database LIMIT 1000")
display(df)

# %%
df = spark.sql("SELECT * FROM SMD_LH.agent_dax_documentation LIMIT 1000")
display(df)

# %%
df = spark.sql("SELECT * FROM SMD_LH.diagrams LIMIT 1000")
display(df)

# %%
df = spark.sql("SELECT * FROM SMD_LH.column_metadata LIMIT 1000")
display(df)

# %%
df = spark.sql("SELECT * FROM SMD_LH.calcdependency LIMIT 1000")
display(df)

# %%
df = spark.sql("SELECT * FROM SMD_LH.data_sources LIMIT 1000")
display(df)

# %%
df = spark.sql("SELECT * FROM SMD_LH.table_partitions LIMIT 1000")
display(df)

# %%
df = spark.sql("SELECT * FROM SMD_LH.columns LIMIT 1000")
display(df)

# %%
df = spark.sql("SELECT * FROM SMD_LH.rls LIMIT 1000")
display(df)
