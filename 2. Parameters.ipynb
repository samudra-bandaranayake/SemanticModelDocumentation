# %%
# Parameters

dax_function = "INFO.CALCDEPENDENCY()"
dax_query = f"EVALUATE {dax_function}"

dax_function_tables = "INFO.TABLES()"
dax_query_tables = f"EVALUATE {dax_function_tables}"

dax_function_columns = "INFO.COLUMNS()"
dax_query_columns = f"EVALUATE {dax_function_columns}"

dax_function_partitions = "INFO.PARTITIONS()"
dax_query_partitions = f"EVALUATE {dax_function_partitions}"

dax_function_roles = "INFO.ROLES()"
dax_query_roles = f"EVALUATE {dax_function_roles}"

dax_function_rolememberships = "INFO.ROLEMEMBERSHIPS()"
dax_query_rolememberships = f"EVALUATE {dax_function_rolememberships}"

dax_function_tablepermissions = "INFO.TABLEPERMISSIONS()"
dax_query_tablepermissions = f"EVALUATE {dax_function_tablepermissions}"



data_agent_name = "oh22is_agent_1.0"

lakehouse_name = 'SMD_LH' # already created one
#-------------------------------------------------------------------------
#workspaceId = "3522c55d-5326-4765-a064-084b40c89a18"
#datasetId = "b4339125-01cd-4482-a6d6-1f2c42150e7b"
#semantic_model_name = "Test_Semantic_Model"
#table_schema = "dbo"
#model_name= "gpt-4o"



#-------------------------------------------------------------------------
#workspaceId = "b8e012c1-9195-435f-8aa5-06d42b538306"
#datasetId = "ba27c51b-ce6f-4482-be95-8d8cbb3a3d41"
#semantic_model_name = "Order Income"
#table_schema = "dbo"
#model_name= "gpt-4o"


#-------------------------------------------------------------------------
workspaceId = "b8e012c1-9195-435f-8aa5-06d42b538306"
datasetId = "b2a99e69-2ee2-4f2a-9bfe-b49be1f58171"
semantic_model_name = "VanArsdel_Sales_Dashboard"
table_schema = "dbo"
model_name= "gpt-4o"
#Claude Sonnet 4.5,Gemini 2.0 Flash, gpt-4o


#-------------------------------------------------------------------------
#workspaceId = "3522c55d-5326-4765-a064-084b40c89a18"
#datasetId = "1c0ce6d8-2c85-46e1-8d79-fb4d989e3b6e"
#semantic_model_name = "Sample Sales Dashboard"
#table_schema = "dbo"
#model_name= "Claude Sonnet 4.5"


#-------------------------------------------------------------------------
#workspaceId = "b8e012c1-9195-435f-8aa5-06d42b538306"
#datasetId = "fb24f095-1ba0-45a4-a109-3ba39b98f561"
#semantic_model_name = "Survey - Copy - Copy"
#table_schema = "dbo"
#model_name= "gpt-4o"


#-------------------------------------------------------------------------
# Out:
# StatementMeta(, , -1, Cancelled, , Cancelled)
