# %% [markdown]
# # Run Notebooks

# %%
mssparkutils.notebook.run("0. Create Environment", 3600)
print("0. Create Environment Notebook execution completed!")

# %% [markdown]
# ## Create the Lakehouse

# %%
mssparkutils.notebook.run("0. Create Lake House", 3600)
print("0. Create Lake House Notebook execution completed!")
# Out:
# StatementMeta(, 738608af-fe04-4b35-af53-288dbe132d29, 4, Finished, Available, Finished, False)
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 mssparkutils.notebook.run("0. Create Lake House", 3600)
#       2 print("0. Create Lake House Notebook execution completed!")
#
# File ~/cluster-env/trident_env/lib/python3.11/site-packages/notebookutils/common/logger.py:37, in deprecated.<locals>.wrapper(*args, **kwargs)
#      35 msg = f"The namespace mssparkutils is deprecated, please use {new_module}.{func.__name__}() instead."
#      36 log4jLogger.warn("[Python] " + msg)
# ---> 37 return func(*args, **kwargs)
#
# File ~/cluster-env/trident_env/lib/python3.11/site-packages/notebookutils/mssparkutils/notebook.py:21, in run(path, timeout_seconds, arguments, workspace)
#      19 @deprecated
#      20 def run(path, timeout_seconds=90, arguments={}, workspace=""):
# ---> 21     return notebook.run(path, timeout_seconds, arguments, workspace)
#
# File ~/cluster-env/trident_env/lib/python3.11/site-packages/notebookutils/notebook.py:18, in run(path, timeout_seconds, arguments, workspace)
#      17 def run(path, timeout_seconds=90, arguments={}, workspace=""):
# ---> 18     exit_val = nb.run(path, timeout_seconds, arguments, workspace)
#      20     if exit_val == constants.STOP_SESSION_REQUEST_EXIT_VAL:
#      21         nb.exit(exit_val)
#
# File ~/cluster-env/trident_env/lib/python3.11/site-packages/notebookutils/mssparkutils/handlers/notebookHandler.py:101, in SynapseNotebookHandler.run(self, path, timeout_seconds, arguments, workspace)
#      99 else:
#     100     self._display_snapshot(j_notebook_run_result)
# --> 101 j_notebook_run_result.throwExceptionIfHave()
#     102 return exit_val
#
# File ~/cluster-env/trident_env/lib/python3.11/site-packages/py4j/java_gateway.py:1322, in JavaMember.__call__(self, *args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
#    1318     args_command +\
#    1319     proto.END_COMMAND_PART
#    1321 answer = self.gateway_client.send_command(command)
# -> 1322 return_value = get_return_value(
#    1323     answer, self.gateway_client, self.target_id, self.name)
#    1325 for temp_arg in temp_args:
#    1326     if hasattr(temp_arg, "_detach"):
#
# File /opt/spark/python/lib/pyspark.zip/pyspark/errors/exceptions/captured.py:179, in capture_sql_exception.<locals>.deco(*a, **kw)
#     177 def deco(*a: Any, **kw: Any) -> Any:
#     178     try:
# --> 179         return f(*a, **kw)
#     180     except Py4JJavaError as e:
#     181         converted = convert_exception(e.java_exception)
#
# File ~/cluster-env/trident_env/lib/python3.11/site-packages/py4j/protocol.py:326, in get_return_value(answer, gateway_client, target_id, name)
#     324 value = OUTPUT_CONVERTER[type](answer[2:], gateway_client)
#     325 if answer[1] == REFERENCE_TYPE:
# --> 326     raise Py4JJavaError(
#     327         "An error occurred while calling {0}{1}{2}.\n".
#     328         format(target_id, ".", name), value)
#     329 else:
#     330     raise Py4JError(
#     331         "An error occurred while calling {0}{1}{2}. Trace:\n{3}\n".
#     332         format(target_id, ".", name, value))
#
# Py4JJavaError: An error occurred while calling o5221.throwExceptionIfHave.
# : com.microsoft.spark.notebook.msutils.NotebookExecutionException: No module named 'sempy_labs'
# ---------------------------------------------------------------------------ModuleNotFoundError                       Traceback (most recent call last)Cell In[4], line 1
# ----> 1 import sempy_labs as labs
#       2 from sempy import fabric
#       3 import sempy
# ModuleNotFoundError: No module named 'sempy_labs'You can check driver log or snapshot for detailed error info! See how to check logs: https://go.microsoft.com/fwlink/?linkid=2157243 .
# 	at com.microsoft.spark.notebook.workflow.JobSessionClient.runCell(JobSessionClient.scala:413)
# 	at com.microsoft.spark.notebook.workflow.JobSessionClient.$anonfun$run$4(JobSessionClient.scala:191)
# 	at com.microsoft.spark.notebook.workflow.JobSessionClient.$anonfun$run$4$adapted(JobSessionClient.scala:174)
# 	at scala.collection.TraversableLike$WithFilter.$anonfun$foreach$1(TraversableLike.scala:985)
# 	at scala.collection.immutable.List.foreach(List.scala:431)
# 	at scala.collection.TraversableLike$WithFilter.foreach(TraversableLike.scala:984)
# 	at com.microsoft.spark.notebook.workflow.JobSessionClient.run(JobSessionClient.scala:174)
# 	at com.microsoft.spark.notebook.msutils.impl.MSNotebookUtilsImpl._run(MSNotebookUtilsImpl.scala:162)
# 	at com.microsoft.spark.notebook.msutils.impl.MSNotebookUtilsImpl.runWithRetry(MSNotebookUtilsImpl.scala:338)
# 	at com.microsoft.spark.notebook.msutils.impl.MSNotebookUtilsImpl.$anonfun$buildDAG$2(MSNotebookUtilsImpl.scala:516)
# 	at com.microsoft.spark.notebook.common.SimpleDAG.$anonfun$executeJob$1(SimpleDAG.scala:311)
# 	at scala.concurrent.Future$.$anonfun$apply$1(Future.scala:659)
# 	at scala.util.Success.$anonfun$map$1(Try.scala:255)
# 	at scala.util.Success.map(Try.scala:213)
# 	at scala.concurrent.Future.$anonfun$map$1(Future.scala:292)
# 	at scala.concurrent.impl.Promise.liftedTree1$1(Promise.scala:33)
# 	at scala.concurrent.impl.Promise.$anonfun$transform$1(Promise.scala:33)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)

# %% [markdown]
# ## Running the Load_Calc_Dependency_Data Notebook

# %%
mssparkutils.notebook.run("4. Load Calc Dependency Data", 3600)
print("4. Load Calc Dependency Data Notebook execution completed!")

# %% [markdown]
# ## Data Transformation and Save Data_Sources & Agent_Dax_Documentation

# %%
mssparkutils.notebook.run("5. Data Transformation", 3600)
print("5. Data Transformation Notebook execution completed!")

# %%
mssparkutils.notebook.run("6. Load Tables Columns", 3600)
print("6. Load Tables Columns Notebook execution completed!")

# %%
mssparkutils.notebook.run("7. Load M Query", 3600)
print("7. Load M Query execution completed!")

# %%
mssparkutils.notebook.run("8. Relationships", 3600)
print("8. Relationships Notebook execution completed!")

# %%
mssparkutils.notebook.run("9. Extract Column List", 3600)
print("9. Extract Column List Notebook execution completed!")

# %%
#mssparkutils.notebook.run("Creating_Semantic_Model_Diagram_LM Copy Large Models", 3600)
mssparkutils.notebook.run("10. Creating Semantic Model Diagram", 3600)#Creating_Semantic_Model_Diagram_LM
print("10. Creating Semantic Model Diagram Notebook execution completed!")

# %%
mssparkutils.notebook.run("11. RLS", 3600)
print("'11. RLS' Notebook execution completed!")

# %%
mssparkutils.notebook.run("12. Create Dim Database Table", 3600)
print("12. Create Dim Database Table execution completed!")

# %% [markdown]
# ## Displaying output

# %%
df = spark.sql("SELECT * FROM SMD_LH.dbo.dim_database LIMIT 1000")
display(df)

# %%
df = spark.sql("SELECT * FROM SMD_LH.dbo.agent_dax_documentation LIMIT 1000")
display(df)

# %%
df = spark.sql("SELECT * FROM SMD_LH.dbo.diagrams LIMIT 1000")
display(df)

# %%
df = spark.sql("SELECT * FROM SMD_LH.dbo.column_metadata LIMIT 1000")
display(df)

# %%
df = spark.sql("SELECT * FROM SMD_LH.dbo.calcdependency LIMIT 1000")
display(df)

# %%
df = spark.sql("SELECT * FROM SMD_LH.dbo.data_sources LIMIT 1000")
display(df)

# %%
df = spark.sql("SELECT * FROM SMD_LH.dbo.table_partitions LIMIT 1000")
display(df)

# %%
df = spark.sql("SELECT * FROM SMD_LH.dbo.columns LIMIT 1000")
display(df)

# %%
df = spark.sql("SELECT * FROM SMD_LH.dbo.rls LIMIT 1000")
display(df)
