# %% [markdown]
# # Run Notebooks

# %% [markdown]
# ## Create the Lakehouse

# %%
mssparkutils.notebook.run("0. Create Lake House", 3600)
print("0. Create Lake House Notebook execution completed!")

# %% [markdown]
# ## Running the Load_Calc_Dependency_Data Notebook

# %%
mssparkutils.notebook.run("4. Load Calc Dependency Data", 3600)
print("4. Load Calc Dependency Data Notebook execution completed!")
# Out:
# StatementMeta(, ea3c924e-c4a1-4f96-8f48-128c60fc0a0e, 5, Finished, Available, Finished, False)
# 4. Load Calc Dependency Data Notebook execution completed!

# %% [markdown]
# ## Data Transformation and Save Data_Sources & Agent_Dax_Documentation

# %%
mssparkutils.notebook.run("5. Data Transformation", 3600)
print("5. Data Transformation Notebook execution completed!")
# Out:
# StatementMeta(, ea3c924e-c4a1-4f96-8f48-128c60fc0a0e, 6, Finished, Available, Finished, False)
# 5. Data Transformation Notebook execution completed!

# %%
mssparkutils.notebook.run("6. Load Tables Columns", 3600)
print("6. Load Tables Columns Notebook execution completed!")
# Out:
# StatementMeta(, ea3c924e-c4a1-4f96-8f48-128c60fc0a0e, 7, Finished, Available, Finished, False)
# 6. Load Tables Columns Notebook execution completed!

# %%
mssparkutils.notebook.run("7. Load M Query", 3600)
print("7. Load M Query execution completed!")
# Out:
# StatementMeta(, ea3c924e-c4a1-4f96-8f48-128c60fc0a0e, 8, Finished, Available, Finished, False)
# 7. Load M Query execution completed!

# %%
mssparkutils.notebook.run("8. Relationships", 3600)
print("8. Relationships Notebook execution completed!")
# Out:
# StatementMeta(, ea3c924e-c4a1-4f96-8f48-128c60fc0a0e, 9, Finished, Available, Finished, False)
# 8. Relationships Notebook execution completed!

# %%
mssparkutils.notebook.run("9. Extract Column List", 3600)
print("9. Extract Column List Notebook execution completed!")
# Out:
# StatementMeta(, ea3c924e-c4a1-4f96-8f48-128c60fc0a0e, 10, Finished, Available, Finished, False)
# 9. Extract Column List Notebook execution completed!

# %%
#mssparkutils.notebook.run("Creating_Semantic_Model_Diagram_LM Copy Large Models", 3600)
mssparkutils.notebook.run("10. Creating Semantic Model Diagram", 3600)#Creating_Semantic_Model_Diagram_LM
print("10. Creating Semantic Model Diagram Notebook execution completed!")
# Out:
# StatementMeta(, ea3c924e-c4a1-4f96-8f48-128c60fc0a0e, 11, Finished, Available, Finished, False)
# 10. Creating Semantic Model Diagram Notebook execution completed!

# %%
mssparkutils.notebook.run("11. RLS", 3600)
print("'11. RLS' Notebook execution completed!")
# Out:
# StatementMeta(, ea3c924e-c4a1-4f96-8f48-128c60fc0a0e, 12, Finished, Available, Finished, False)
# '11. RLS' Notebook execution completed!

# %%
mssparkutils.notebook.run("12. Create Dim Database Table", 3600)
print("12. Create Dim Database Table execution completed!")
# Out:
# StatementMeta(, ea3c924e-c4a1-4f96-8f48-128c60fc0a0e, 13, Finished, Available, Finished, False)
# 12. Create Dim Database Table execution completed!

# %% [markdown]
# ## Displaying output

# %%
df = spark.sql("SELECT * FROM SMD_LH.dbo.dim_database LIMIT 1000")
display(df)
# Out:
# StatementMeta(, ea3c924e-c4a1-4f96-8f48-128c60fc0a0e, 14, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 5c611120-ed88-461c-b1b2-148ed3cc499c)

# %%
df = spark.sql("SELECT * FROM SMD_LH.dbo.agent_dax_documentation LIMIT 1000")
display(df)
# Out:
# StatementMeta(, ea3c924e-c4a1-4f96-8f48-128c60fc0a0e, 15, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 706efd9d-c8fe-43c8-8e02-da1f769c4cbf)

# %%
df = spark.sql("SELECT * FROM SMD_LH.dbo.diagrams LIMIT 1000")
display(df)
# Out:
# StatementMeta(, ea3c924e-c4a1-4f96-8f48-128c60fc0a0e, 16, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, d493ae40-9e74-4371-aee8-42c049e6b8b6)

# %%
df = spark.sql("SELECT * FROM SMD_LH.dbo.column_metadata LIMIT 1000")
display(df)
# Out:
# StatementMeta(, ea3c924e-c4a1-4f96-8f48-128c60fc0a0e, 17, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 0266f964-be70-4c87-a8f7-f3c5ec7ca237)

# %%
df = spark.sql("SELECT * FROM SMD_LH.dbo.calcdependency LIMIT 1000")
display(df)
# Out:
# StatementMeta(, ea3c924e-c4a1-4f96-8f48-128c60fc0a0e, 18, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 15cd7147-0e2a-4f57-96b1-06589309756f)

# %%
df = spark.sql("SELECT * FROM SMD_LH.dbo.data_sources LIMIT 1000")
display(df)
# Out:
# StatementMeta(, ea3c924e-c4a1-4f96-8f48-128c60fc0a0e, 19, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 318cab10-a261-4492-b4b2-05950d233dad)

# %%
df = spark.sql("SELECT * FROM SMD_LH.dbo.table_partitions LIMIT 1000")
display(df)
# Out:
# StatementMeta(, ea3c924e-c4a1-4f96-8f48-128c60fc0a0e, 20, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 70fd3dae-1f4d-4ab2-a230-4393c51f629c)

# %%
df = spark.sql("SELECT * FROM SMD_LH.dbo.columns LIMIT 1000")
display(df)
# Out:
# StatementMeta(, ea3c924e-c4a1-4f96-8f48-128c60fc0a0e, 21, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, fe79dfff-af3f-4bff-8f8a-a7759385bdff)

# %%
df = spark.sql("SELECT * FROM SMD_LH.dbo.rls LIMIT 1000")
display(df)
# Out:
# StatementMeta(, ea3c924e-c4a1-4f96-8f48-128c60fc0a0e, 22, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 8b300464-1893-475b-b697-a2a3ab5e581d)
