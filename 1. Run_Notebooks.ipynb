# %% [markdown]
# # Run Notebooks

# %% [markdown]
# ## Running the Load_Calc_Dependency_Data Notebook

# %%
mssparkutils.notebook.run("Load_Calc_Dependency_Data", 3600)
print("Load_Calc_Dependency_Data Notebook execution completed!")
# Out:
# StatementMeta(, 540812a1-11f0-4e4d-bc15-08ddc9a2ef17, 5, Finished, Available, Finished, False)
# Load_Calc_Dependency_Data Notebook execution completed!

# %% [markdown]
# ## Data Transformation and Save Data_Sources & Agent_Dax_Documentation

# %%
mssparkutils.notebook.run("Data_Transformation", 3600)
print("Data_Transformation Notebook execution completed!")
# Out:
# StatementMeta(, 540812a1-11f0-4e4d-bc15-08ddc9a2ef17, 6, Finished, Available, Finished, False)
# Data_Transformation Notebook execution completed!

# %%
mssparkutils.notebook.run("Load_Tables_Columns", 3600)
print("Load_Tables_Columns Notebook execution completed!")
# Out:
# StatementMeta(, 540812a1-11f0-4e4d-bc15-08ddc9a2ef17, 7, Finished, Available, Finished, False)
# Load_Tables_Columns Notebook execution completed!

# %%
mssparkutils.notebook.run("Load_M_Query", 3600)
print("Load_M_Query execution completed!")
# Out:
# StatementMeta(, 540812a1-11f0-4e4d-bc15-08ddc9a2ef17, 8, Finished, Available, Finished, False)
# Load_M_Query execution completed!

# %%
mssparkutils.notebook.run("Relationships", 3600)
print("Extract Column List Notebook execution completed!")
# Out:
# StatementMeta(, 540812a1-11f0-4e4d-bc15-08ddc9a2ef17, 9, Finished, Available, Finished, False)
# Extract Column List Notebook execution completed!

# %%
mssparkutils.notebook.run("Extract_Column_List_Copy", 3600)
print("Extract Column List Notebook execution completed!")
# Out:
# StatementMeta(, 540812a1-11f0-4e4d-bc15-08ddc9a2ef17, 10, Finished, Available, Finished, False)
# Extract Column List Notebook execution completed!

# %%
#mssparkutils.notebook.run("Creating_Semantic_Model_Diagram_LM Copy Large Models", 3600)
mssparkutils.notebook.run("Creating_Semantic_Model_Diagram_LM", 3600)#Creating_Semantic_Model_Diagram_LM
print("Creating_Semantic_Model_Diagram Notebook execution completed!")
# Out:
# StatementMeta(, 540812a1-11f0-4e4d-bc15-08ddc9a2ef17, 11, Finished, Available, Finished, False)
# Creating_Semantic_Model_Diagram Notebook execution completed!

# %%
mssparkutils.notebook.run("RLS", 3600)
print("Create RLS Table execution completed!")
# Out:
# StatementMeta(, 540812a1-11f0-4e4d-bc15-08ddc9a2ef17, 16, Finished, Available, Finished, False)
# Create RLS Table execution completed!

# %%
mssparkutils.notebook.run("Create Dim_Database Table", 3600)
print("Create Dim_Database Table execution completed!")
# Out:
# StatementMeta(, 540812a1-11f0-4e4d-bc15-08ddc9a2ef17, 15, Finished, Available, Finished, False)
# Create Dim_Database Table execution completed!

# %% [markdown]
# ## Displaying output

# %%
df = spark.sql("SELECT * FROM SMD_LH.dbo.dim_database LIMIT 1000")
display(df)
# Out:
# StatementMeta(, 540812a1-11f0-4e4d-bc15-08ddc9a2ef17, -1, Cancelled, , Cancelled, True)

# %%
df = spark.sql("SELECT * FROM SMD_LH.dbo.agent_dax_documentation LIMIT 1000")
display(df)
# Out:
# StatementMeta(, 540812a1-11f0-4e4d-bc15-08ddc9a2ef17, -1, Cancelled, , Cancelled, True)

# %%
df = spark.sql("SELECT * FROM SMD_LH.dbo.diagrams LIMIT 1000")
display(df)
# Out:
# StatementMeta(, 540812a1-11f0-4e4d-bc15-08ddc9a2ef17, -1, Cancelled, , Cancelled, True)

# %%
df = spark.sql("SELECT * FROM SMD_LH.dbo.column_metadata LIMIT 1000")
display(df)
# Out:
# StatementMeta(, 540812a1-11f0-4e4d-bc15-08ddc9a2ef17, -1, Cancelled, , Cancelled, True)

# %%
df = spark.sql("SELECT * FROM SMD_LH.dbo.calcdependency LIMIT 1000")
display(df)
# Out:
# StatementMeta(, 540812a1-11f0-4e4d-bc15-08ddc9a2ef17, -1, Cancelled, , Cancelled, True)

# %%
df = spark.sql("SELECT * FROM SMD_LH.dbo.data_sources LIMIT 1000")
display(df)
# Out:
# StatementMeta(, 540812a1-11f0-4e4d-bc15-08ddc9a2ef17, -1, Cancelled, , Cancelled, True)

# %%
df = spark.sql("SELECT * FROM SMD_LH.dbo.table_partitions LIMIT 1000")
display(df)
# Out:
# StatementMeta(, 540812a1-11f0-4e4d-bc15-08ddc9a2ef17, -1, Cancelled, , Cancelled, True)

# %%
df = spark.sql("SELECT * FROM SMD_LH.dbo.columns LIMIT 1000")
display(df)
# Out:
# StatementMeta(, 540812a1-11f0-4e4d-bc15-08ddc9a2ef17, -1, Cancelled, , Cancelled, True)

# %%
df = spark.sql("SELECT * FROM SMD_LH.dbo.rls LIMIT 1000")
display(df)
